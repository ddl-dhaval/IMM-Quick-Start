# %%
import pyarrow.parquet as pq
import pandas as pd

# %% [markdown]
# #### Load the path to the prediction dataset. For each model API version, a new folder is created

# %%
# *** fill in your model version ID (found in versions tab, it is not the model ID) ***
#this is also found if you look at the contents of your predictions dataset

model_version_id= "6355f0b1206da26c42e63509" 
#example model_version_id="618b7b8d4064b12fe8c31fdf"

path = '/mnt/data/prediction_data/{}/'.format(model_version_id)

# %% [markdown]
# #### Load the entire directory as a parquet object into a pandas dataframe

# %%
df = pd.read_parquet(path)

# %% [markdown]
# #### You can now query the dataframe for various ranges of data you might be interested in

# %%
df[(df['timestamp'] > '2021-11-10')]# & (df['timestamp'] < '2021-11-12')]
# Out:
#         lat     long  sqft_living15  sqft_lot15  bedrooms  bathrooms  \
# 0    8.6489   4.5412         7.2491      7.9346    4.4737     9.8650
# 1    8.9661   8.8853         2.9487     10.8677    2.0018     9.9762
# 2    2.0528   4.6756         4.4126      3.1998    3.3029    10.2870
# 3    1.7256  10.7933         4.7511      1.5870    7.4104     6.0221
# 4    2.8261   6.0528         4.5168      1.5676    8.7761     7.2156
# ..      ...      ...            ...         ...       ...        ...
# 995  8.2787   9.7535         8.9425      6.7287    2.9095     7.3811
# 996  1.0172   6.9463         1.8746      7.1983    5.5866     2.2113
# 997  6.0926   6.5067         9.6420      3.6651    9.3638     2.7538
# 998  5.5147   6.2197         2.1889      9.5730    3.5276     4.0058
# 999  2.6685   8.0094        10.3780      8.6684    1.7829     4.2725
#
#      sqft_living  sqft_lot   floors  waterfront  ...  yr_built  yr_renovated  \
# 0         6.4419    6.9743   8.9924      2.5906  ...    2.2787        6.8778
# 1        10.0065    1.7246   4.0931      3.6477  ...    7.5043        9.4725
# 2         2.9649    7.3153   4.9672      2.2341  ...    3.5365        3.7613
# 3         8.6436   10.5354   4.6999      1.4036  ...    8.5614        4.8985
# 4         6.3883    9.6066   8.1197      9.2929  ...    7.0933       10.0762
# ..           ...       ...      ...         ...  ...       ...           ...
# 995       8.8106    6.8266   1.4014      4.1141  ...    6.1032        9.9253
# 996       2.0810    9.5209   9.1086      7.3851  ...    6.7384        1.9494
# 997       5.1294   10.2957   1.8567      3.9077  ...    9.4049        4.7672
# 998       7.7038    3.5826  10.8500      1.0213  ...    1.6952        6.6136
# 999       2.0094    5.6173   6.1032      5.3352  ...   10.6944        1.4525
#
#      zipcode   price                              event_id  \
# 0     6.2954  570000  b8089347-8a4b-4491-9329-afd839222d4c
